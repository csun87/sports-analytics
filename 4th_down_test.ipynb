# %%
import pandas as pd
import requests
import json

# %%
# --- Configuration ---
API_KEY = "gmycKK7YxkJ0nWcdaP6X2a8Zd8a+suoKM3f6T/owScQ7UhLtm6BvOW64EK1NOpHm"
BASE_URL = "https://api.collegefootballdata.com/"
TARGET_TEAM = "Notre Dame"
SEASONS = [2024, 2025] # Previous and Current Season

# --- Headers for Authentication ---
headers = {
    "Authorization": f"Bearer {API_KEY}"
}

# %%
def fetch_plays_by_year(year):
    """
    Fetches play-by-play data, prints errors, and returns data.
    """
    params = {
        'year': year,
        'team': TARGET_TEAM,
        'seasonType': 'both'
    }

    print(f"Attempting to fetch data for {TARGET_TEAM} - {year} season...")
    
    try:
        response = requests.get(BASE_URL + "games", headers=headers, params=params)
        
        # Check for non-200 status codes (like 400, 401, 404)
        if response.status_code != 200:
            print("--- API ERROR DETECTED ---")
            print(f"Status Code: {response.status_code}")
            
            # The CFBD API often provides a JSON error message
            try:
                error_details = response.json()
                print(f"API Message: {error_details.get('error', 'No specific error message found in JSON.')}")
            except json.JSONDecodeError:
                print(f"Raw Response: {response.text}")
            
            response.raise_for_status() # Raise the HTTPError
        data = response.json()
        print(f"Successfully retrieved {len(data)} plays for {year}.")
        return data

    except requests.exceptions.RequestException as e:
        print(f"Request failed: {e}")
        return []

# %%
# --- Main Execution ---
all_plays_data = []

for year in SEASONS:
    plays = fetch_plays_by_year(year)
    all_plays_data.extend(plays)

# Convert the combined list of dictionaries into a Pandas DataFrame
if all_plays_data:

    df = pd.DataFrame(all_plays_data)
    print("\n--- Data Summary ---")
    print(f"Total plays retrieved for {TARGET_TEAM}: {len(df)}")
else:
    print("\nNo data retrieved. Please check your API key and connection.")
# Out:
# Attempting to fetch data for Notre Dame - 2024 season...
# [{"id":401628332,"season":2024,"week":1,"seasonType":"regular","startDate":"2024-08-31T23:30:00.000Z","startTimeTBD":false,"completed":true,"neutralSite":false,"conferenceGame":false,"attendance":null,"venueId":3795,"venue":"Kyle Field","homeId":245,"homeTeam":"Texas A&M","homeClassification":"fbs","homeConference":"SEC","homePoints":13,"homeLineScores":[3,3,0,7],"homePostgameWinProbability":0.08384600052782992,"homePregameElo":1681,"homePostgameElo":1677,"awayId":87,"awayTeam":"Notre Dame","awayClassification":"fbs","awayConference":"FBS Independents","awayPoints":23,"awayLineScores":[3,3,7,10],"awayPostgameWinProbability":0.9161539994721701,"awayPregameElo":1884,"awayPostgameElo":1888,"excitementIndex":6.4724625583,"highlights":"","notes":null},{"id":401628977,"season":2024,"week":2,"seasonType":"regular","startDate":"2024-09-07T19:30:00.000Z","startTimeTBD":false,"completed":true,"neutralSite":false,"conferenceGame":false,"attendance":77622,"venueId":3855,"venue":"Notre Dame Stadium","homeId":87,"homeTeam":"Notre Dame","homeClassification":"fbs","homeConference":"FBS Independents","homePoints":14,"homeLineScores":[7,0,7,0],"homePostgameWinProbability":0.22276720328304617,"homePregameElo":1888,"homePostgameElo":1858,"awayId":2459,"awayTeam":"Northern Illinois","awayClassification":"fbs","awayConference":"Mid-American","awayPoints":16,"awayLineScores":[10,3,0,3],"awayPostgameWinProbability":0.7772327967169539,"awayPregameElo":1446,"awayPostgameElo":1476,"excitementIndex":4.9100949395,"highlights":"","notes":null},{"id":401628978,"season":2024,"week":3,"seasonType":"regular","startDate":"2024-09-14T19:30:00.000Z","startTimeTBD":false,"completed":true,"neutralSite":false,"conferenceGame":false,"attendance":61441,"venueId":3907,"venue":"Ross-Ade Stadium","homeId":2509,"homeTeam":"Purdue","homeClassification":"fbs","homeConference":"Big Ten","homePoints":7,"homeLineScores":[0,0,7,0],"homePostgameWinProbability":0.0002993282026749188,"homePregameElo":1492,"homePostgameElo":1358,"awayId":87,"awayTeam":"Notre Dame","awayClassification":"fbs","awayConference":"FBS Independents","awayPoints":66,"awayLineScores":[14,28,10,14],"awayPostgameWinProbability":0.9997006717973251,"awayPregameElo":1858,"awayPostgameElo":1992,"excitementIndex":2.1112922952,"highlights":"","notes":null},{"id":401628979,"season":2024,"week":4,"seasonType":"regular","startDate":"2024-09-21T19:30:00.000Z","startTimeTBD":false,"completed":true,"neutralSite":false,"conferenceGame":false,"attendance":77622,"venueId":3855,"venue":"Notre Dame Stadium","homeId":87,"homeTeam":"Notre Dame","homeClassification":"fbs","homeConference":"FBS Independents","homePoints":28,"homeLineScores":[0,14,7,7],"homePostgameWinProbability":0.9986494251644964,"homePregameElo":1992,"homePostgameElo":2000,"awayId":193,"awayTeam":"Miami (OH)","awayClassification":"fbs","awayConference":"Mid-American","awayPoints":3,"awayLineScores":[0,3,0,0],"awayPostgameWinProbability":0.001350574835503604,"awayPregameElo":1458,"awayPostgameElo":1450,"excitementIndex":6.0816618423,"highlights":"","notes":null},{"id":401628980,"season":2024,"week":5,"seasonType":"regular","startDate":"2024-09-28T19:30:00.000Z","startTimeTBD":false,"completed":true,"neutralSite":false,"conferenceGame":false,"attendance":77622,"venueId":3855,"venue":"Notre Dame Stadium","homeId":87,"homeTeam":"Notre Dame","homeClassification":"fbs","homeConference":"FBS Independents","homePoints":31,"homeLineScores":[21,3,0,7],"homePostgameWinProbability":0.8595368472597268,"homePregameElo":2000,"homePostgameElo":1994,"awayId":97,"awayTeam":"Louisville","awayClassification":"fbs","awayConference":"ACC","awayPoints":24,"awayLineScores":[7,7,0,10],"awayPostgameWinProbability":0.1404631527402732,"awayPregameElo":1711,"awayPostgameElo":1717,"excitementIndex":7.3478032351,"highlights":"","notes":null},{"id":401628981,"season":2024,"week":7,"seasonType":"regular","startDate":"2024-10-12T19:30:00.000Z","startTimeTBD":false,"completed":true,"neutralSite ...
# Successfully retrieved 16 plays for 2024.
# Attempting to fetch data for Notre Dame - 2025 season...
# [{"id":401754522,"season":2025,"week":1,"seasonType":"regular","startDate":"2025-08-31T23:30:00.000Z","startTimeTBD":false,"completed":true,"neutralSite":false,"conferenceGame":false,"attendance":null,"venueId":3948,"venue":"Hard Rock Stadium","homeId":2390,"homeTeam":"Miami","homeClassification":"fbs","homeConference":"ACC","homePoints":27,"homeLineScores":[0,14,7,6],"homePostgameWinProbability":0.9616499543190002,"homePregameElo":1736,"homePostgameElo":1743,"awayId":87,"awayTeam":"Notre Dame","awayClassification":"fbs","awayConference":"FBS Independents","awayPoints":24,"awayLineScores":[0,7,0,17],"awayPostgameWinProbability":0.038350045680999756,"awayPregameElo":2173,"awayPostgameElo":2166,"excitementIndex":5.318312492748594,"highlights":"","notes":null},{"id":401752707,"season":2025,"week":3,"seasonType":"regular","startDate":"2025-09-13T23:30:00.000Z","startTimeTBD":false,"completed":true,"neutralSite":false,"conferenceGame":false,"attendance":null,"venueId":3855,"venue":"Notre Dame Stadium","homeId":87,"homeTeam":"Notre Dame","homeClassification":"fbs","homeConference":"FBS Independents","homePoints":40,"homeLineScores":[14,10,7,9],"homePostgameWinProbability":0.3599589765071869,"homePregameElo":2166,"homePostgameElo":2141,"awayId":245,"awayTeam":"Texas A&M","awayClassification":"fbs","awayConference":"SEC","awayPoints":41,"awayLineScores":[7,21,3,10],"awayPostgameWinProbability":0.6400410234928131,"awayPregameElo":1724,"awayPostgameElo":1749,"excitementIndex":8.103345635698446,"highlights":"","notes":null},{"id":401752848,"season":2025,"week":4,"seasonType":"regular","startDate":"2025-09-20T19:30:00.000Z","startTimeTBD":false,"completed":true,"neutralSite":false,"conferenceGame":false,"attendance":null,"venueId":3855,"venue":"Notre Dame Stadium","homeId":87,"homeTeam":"Notre Dame","homeClassification":"fbs","homeConference":"FBS Independents","homePoints":56,"homeLineScores":[14,21,21,0],"homePostgameWinProbability":1,"homePregameElo":2141,"homePostgameElo":2126,"awayId":2509,"awayTeam":"Purdue","awayClassification":"fbs","awayConference":"Big Ten","awayPoints":30,"awayLineScores":[7,16,0,7],"awayPostgameWinProbability":0,"awayPregameElo":1310,"awayPostgameElo":1325,"excitementIndex":4.592865576529613,"highlights":"","notes":null},{"id":401752717,"season":2025,"week":5,"seasonType":"regular","startDate":"2025-09-27T16:00:00.000Z","startTimeTBD":false,"completed":true,"neutralSite":false,"conferenceGame":false,"attendance":null,"venueId":3887,"venue":"Razorback Stadium","homeId":8,"homeTeam":"Arkansas","homeClassification":"fbs","homeConference":"SEC","homePoints":13,"homeLineScores":[3,10,0,0],"homePostgameWinProbability":0.07294102758169174,"homePregameElo":1677,"homePostgameElo":1608,"awayId":87,"awayTeam":"Notre Dame","awayClassification":"fbs","awayConference":"FBS Independents","awayPoints":56,"awayLineScores":[14,28,7,7],"awayPostgameWinProbability":0.9270589724183083,"awayPregameElo":2126,"awayPostgameElo":2195,"excitementIndex":3.1141392481338106,"highlights":"","notes":null},{"id":401757165,"season":2025,"week":6,"seasonType":"regular","startDate":"2025-10-04T19:30:00.000Z","startTimeTBD":false,"completed":true,"neutralSite":false,"conferenceGame":false,"attendance":null,"venueId":3855,"venue":"Notre Dame Stadium","homeId":87,"homeTeam":"Notre Dame","homeClassification":"fbs","homeConference":"FBS Independents","homePoints":28,"homeLineScores":[6,8,7,7],"homePostgameWinProbability":0.9840602278709412,"homePregameElo":2195,"homePostgameElo":2194,"awayId":68,"awayTeam":"Boise State","awayClassification":"fbs","awayConference":"Mountain West","awayPoints":7,"awayLineScores":[0,7,0,0],"awayPostgameWinProbability":0.015939772129058838,"awayPregameElo":1653,"awayPostgameElo":1654,"excitementIndex":4.635698235011022,"highlights":"","notes":null},{"id":401754562,"season":2025,"week":7,"seasonType":"regular","startDate":"2025-10-11T19:30:00.000Z","startTimeTBD":false,"completed":true,"neutralSite":false,"conferenceGame" ...
# Successfully retrieved 12 plays for 2025.
#
# --- Data Summary ---
# Total plays retrieved for Notre Dame: 28

# %%
df.head()
# Out:
#           id  season  week seasonType                 startDate  startTimeTBD  \
# 0  401628332    2024     1    regular  2024-08-31T23:30:00.000Z         False
# 1  401628977    2024     2    regular  2024-09-07T19:30:00.000Z         False
# 2  401628978    2024     3    regular  2024-09-14T19:30:00.000Z         False
# 3  401628979    2024     4    regular  2024-09-21T19:30:00.000Z         False
# 4  401628980    2024     5    regular  2024-09-28T19:30:00.000Z         False
#
#    completed  neutralSite  conferenceGame  attendance  ...  \
# 0       True        False           False         NaN  ...
# 1       True        False           False     77622.0  ...
# 2       True        False           False     61441.0  ...
# 3       True        False           False     77622.0  ...
# 4       True        False           False     77622.0  ...
#
#    awayClassification    awayConference  awayPoints    awayLineScores  \
# 0                 fbs  FBS Independents          23     [3, 3, 7, 10]
# 1                 fbs      Mid-American          16     [10, 3, 0, 3]
# 2                 fbs  FBS Independents          66  [14, 28, 10, 14]
# 3                 fbs      Mid-American           3      [0, 3, 0, 0]
# 4                 fbs               ACC          24     [7, 7, 0, 10]
#
#   awayPostgameWinProbability awayPregameElo  awayPostgameElo excitementIndex  \
# 0                   0.916154           1884             1888        6.472463
# 1                   0.777233           1446             1476        4.910095
# 2                   0.999701           1858             1992        2.111292
# 3                   0.001351           1458             1450        6.081662
# 4                   0.140463           1711             1717        7.347803
#
#    highlights  notes
# 0               None
# 1               None
# 2               None
# 3               None
# 4               None
#
# [5 rows x 33 columns]

# %%
df_2024 = pd.DataFrame()
for week_number in range(1, 15):
    plays_url = BASE_URL + "/plays"
    params = {
        "year" : 2024,
        "week" : week_number,
        "seasonType" : "both",
        "classification" : "fbs"
    }
    response = requests.get(plays_url, headers=headers, params=params)
    if response.status_code == 200:
        data = response.json()
        week_df = pd.DataFrame(data)
        df_2024 = pd.concat([df_2024, week_df], ignore_index=True)
    else:
        print("--- API ERROR DETECTED ---")
        print(f"Status Code: {response.status_code}")
        
        # The CFBD API often provides a JSON error message
        try:
            error_details = response.json()
            print(f"API Message: {error_details.get('error', 'No specific error message found in JSON.')}")
        except json.JSONDecodeError:
            print(f"Raw Response: {response.text}")
            break

# %%
df_2024.to_csv("./regular_season_2024.csv")

# %%
df_2024.columns.values
# Out:
# array(['gameId', 'driveId', 'id', 'driveNumber', 'playNumber', 'offense',
#        'offenseConference', 'offenseScore', 'defense',
#        'defenseConference', 'defenseScore', 'home', 'away', 'period',
#        'clock', 'offenseTimeouts', 'defenseTimeouts', 'yardline',
#        'yardsToGoal', 'down', 'distance', 'yardsGained', 'scoring',
#        'playType', 'playText', 'ppa', 'wallclock'], dtype=object)

# %%
# First, let us estimate the success rate of field goals
fg_df = df_2024[df_2024["playType"].str.contains("Field Goal")]
fg_df = fg_df[["offense", "defense", "yardsToGoal", "scoring", "playType", "playText"]]

# %%
fg_df[fg_df["offense"] == "Notre Dame"]
# Out:
#            offense            defense  yardsToGoal  scoring  \
# 68      Notre Dame         Penn State           23     True
# 157     Notre Dame         Penn State           23     True
# 201     Notre Dame            Georgia           26     True
# 226     Notre Dame            Georgia           30     True
# 271     Notre Dame            Georgia           29     True
# 5292    Notre Dame            Indiana           31     True
# 5392    Notre Dame            Indiana           15     True
# 5419    Notre Dame            Indiana           19    False
# 24927   Notre Dame          Texas A&M           28     True
# 24968   Notre Dame          Texas A&M            8     True
# 25347   Notre Dame         Ohio State            9    False
# 25398   Notre Dame          Texas A&M           28     True
# 29140   Notre Dame  Northern Illinois           30    False
# 29370   Notre Dame  Northern Illinois           44    False
# 44832   Notre Dame             Purdue           24     True
# 63748   Notre Dame         Louisville           30     True
# 93687   Notre Dame       Georgia Tech           24     True
# 93704   Notre Dame       Georgia Tech           28    False
# 102714  Notre Dame               Navy           18    False
# 102766  Notre Dame               Navy           14     True
# 122247  Notre Dame      Florida State           24    False
# 122308  Notre Dame      Florida State           10     True
# 131061  Notre Dame           Virginia           36    False
# 131123  Notre Dame           Virginia           18    False
# 139709  Notre Dame               Army           30    False
# 139729  Notre Dame               Army           12    False
# 156009  Notre Dame                USC            9    False
#
#                   playType                                           playText
# 68         Field Goal Good                          Mitch Jeter 41 yd FG GOOD
# 157        Field Goal Good                          Mitch Jeter 41 yd FG GOOD
# 201        Field Goal Good                          Mitch Jeter 44 yd FG GOOD
# 226        Field Goal Good                          Mitch Jeter 48 yd FG GOOD
# 271        Field Goal Good                          Mitch Jeter 47 yd FG GOOD
# 5292       Field Goal Good                          Mitch Jeter 49 yd FG GOOD
# 5392       Field Goal Good                          Mitch Jeter 33 yd FG GOOD
# 5419    Blocked Field Goal  Mitch Jeter 37 yd FG BLOCKED blocked by James ...
# 24927      Field Goal Good                          Mitch Jeter 46 yd FG GOOD
# 24968      Field Goal Good                          Mitch Jeter 26 yd FG GOOD
# 25347    Field Goal Missed                        Mitch Jeter 27 yd FG MISSED
# 25398      Field Goal Good                          Mitch Jeter 46 yd FG GOOD
# 29140   Blocked Field Goal  Mitch Jeter 48 yd FG blocked by Cade Haberman,...
# 29370   Blocked Field Goal      Mitch Jeter 62 yd FG blocked by Cade Haberman
# 44832      Field Goal Good                          Mitch Jeter 42 yd FG GOOD
# 63748      Field Goal Good                          Mitch Jeter 48 yd FG GOOD
# 93687      Field Goal Good                           Zac Yoakam 42 yd FG GOOD
# 93704    Field Goal Missed                         Zac Yoakam 46 yd FG MISSED
# 102714   Field Goal Missed                         Zac Yoakam 36 yd FG MISSED
# 102766     Field Goal Good                           Zac Yoakam 32 yd FG GOOD
# 122247   Field Goal Missed                        Mitch Jeter 42 yd FG MISSED
# 122308     Field Goal Good                          Mitch Jeter 28 yd FG GOOD
# 131061   Field Goal Missed                   Marcello Diomede 54 yd FG MISSED
# 131123   Field Goal Missed                         Zac Yoakam 36 yd FG MISSED
# 139709   Field Goal Missed                        Mitch Jeter 48 yd FG MISSED
# 139729  Blocked Field Goal  Mitch Jeter 30 yd FG BLOCKED blocked by Elo Mo...
# 156009   Field Goal Missed                        Mitch Jeter 27 yd FG MISSED
